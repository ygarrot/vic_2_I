# %%
from main import *

# %matplotlib inline
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
# %load_ext autoreload
# %autoreload 2
# pcv.params.debug = 'plot'
# Out:
# interactive(children=(IntSlider(value=160, description='i_b_thresh', max=480, min=-160), IntSlider(value=160, …
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tutorial()
# Out:
# interactive(children=(IntSlider(value=147, description='i_b_thresh', max=441, min=-147), IntSlider(value=112, …
